# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('example2.csv')
data2 = pd.read_csv('example.csv')
data3 = pd.read_csv('example3.csv')

# %%
data1 = data1.fillna(0)
data2 = data2.fillna(0)
data3 = data3.fillna(0)

# %%
# Normalize data1's Data
i = 0
data1['Kirtan - actionable'] = data1['Kirtan - actionable'].apply(str)
for val in data1['Kirtan - eval']: 
    if val == 't':
        data1.at[data1.index[i],'Kirtan - eval'] = 'T'
        data1.at[data1.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 'T':
        data1.at[data1.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 0:
        data1.at[data1.index[i],'Kirtan - eval'] = 'F'
        data1.at[data1.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 'ta' or val == 'TA':
        data1.at[data1.index[i],'Kirtan - eval'] = 'T'
        data1.at[data1.index[i],'Kirtan - actionable'] = 'A'
    
    i = i + 1
    
    
i = 0
#data1['Reeshad - actionable'] = data1['Reeshad - actionable'].apply(str)
for val in data1['Reeshad - actionable']: 
#    if val == 't':
#        data1.at[data1.index[i],'Reeshad - eval'] = 'T'
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
#    if val == 'T':
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
#    if val == 0:
#        data1.at[data1.index[i],'Reeshad - eval'] = 'F'
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
    if val == 'FA':
        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
    if val == 'TA':
        data1.at[data1.index[i],'Reeshad - actionable'] = 'A'
    
    i = i + 1
    

i = 0
#data1['Divyansh - actionable'] = data1['Divyansh - actionable'].apply(str)
for val1 in data1['Divyansh - eval']: 
    if val1 == 'n':
        data1.at[data1.index[i],'Divyansh - eval'] = 'F'
        data1.at[data1.index[i],'Divyansh - actionable'] = 'NA'
        
    if val1 == 'y':
        data1.at[data1.index[i],'Divyansh - eval'] = 'T'
    i = i + 1
    

i = 0        
for val2 in data1['Divyansh - actionable']:
    if val2 == '-':
        data1.at[data1.index[i],'Divyansh - actionable'] = 'NA'
        
    if val2 == 'y':
        data1.at[data1.index[i],'Divyansh - actionable'] = 'A'
        
    if val2 == 'n':
        data1.at[data1.index[i],'Divyansh - actionable'] = 'NA'
    
    i = i + 1
    
data1
# Out:
#                                                   text Kirtan - eval  \
# 0    Drinking in Calgary's parks: pilot program a s...             F
# 1    Wow. “Starting June 1st, COVID restrictions pe...             T
# 2    Drinking in Calgary parks could soon be a real...             T
# 3    Calgary should get with the times and join the...             T
# 4    @scryed88 @cityofcalgary I’m the last guy on t...             T
# ..                                                 ...           ...
# 106  A new proposal could see Calgarians able to en...             T
# 107  When you’re technically allowed to start drink...             F
# 108  Starting tomorrow (June 1), Calgarians will be...             F
# 109  A Calgary city councillor is putting together ...             F
# 110  The city of Calgary is gonna have a vote to de...             T
#
#     Kirtan - actionable Reeshad - eval Reeshad - actionable Divyansh - eval  \
# ...

# %%
# Normalize data2's Data
i = 0
#data2['Kirtan - actionable'] = data2['Kirtan - actionable'].apply(str)
data2['Kirtan - eval'] = data2['Kirtan']
for val in data2['Kirtan - eval']: 
    if val == 't':
        data2.at[data2.index[i],'Kirtan - eval'] = 'T'
        data2.at[data2.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 'T':
        data2.at[data2.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 0:
        data2.at[data2.index[i],'Kirtan - eval'] = 'F'
        data2.at[data2.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 'ta' or val == 'TA':
        data2.at[data2.index[i],'Kirtan - eval'] = 'T'
        data2.at[data2.index[i],'Kirtan - actionable'] = 'A'
    
    i = i + 1
    
    
i = 0
#data1['Reeshad - actionable'] = data1['Reeshad - actionable'].apply(str)
for val in data2['Reeshad - actionable']: 
#    if val == 't':
#        data1.at[data1.index[i],'Reeshad - eval'] = 'T'
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
#    if val == 'T':
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
#    if val == 0:
#        data1.at[data1.index[i],'Reeshad - eval'] = 'F'
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
    if val == 'FA':
        data2.at[data2.index[i],'Reeshad - actionable'] = 'NA'
        
    if val == 'TA':
        data2.at[data2.index[i],'Reeshad - actionable'] = 'A'
    
    i = i + 1
    

i = 0
#data1['Divyansh - actionable'] = data1['Divyansh - actionable'].apply(str)
for val1 in data2['Divyansh - eval']: 
    if val1 == 'n':
        data2.at[data2.index[i],'Divyansh - eval'] = 'F'
        data2.at[data2.index[i],'Divyansh - actionable'] = 'NA'
        
    if val1 == 'y':
        data2.at[data2.index[i],'Divyansh - eval'] = 'T'
    i = i + 1
    

i = 0        
for val2 in data2['Divyansh - actionable']:
    if val2 == '-':
        data2.at[data2.index[i],'Divyansh - actionable'] = 'NA'
        
    if val2 == 'y':
        data2.at[data2.index[i],'Divyansh - actionable'] = 'A'
        
    if val2 == 'n':
        data2.at[data2.index[i],'Divyansh - actionable'] = 'NA'
    
    i = i + 1
    

data2 = data2.drop(columns=['Kirtan'])
    
data2
# Out:
#                                                   text Reeshan - eval  \
# 0    I think the proposed bike lane for 2 Ave NW mi...              T
# 1    @drkomanduri People are really homing in on th...              T
# 2    Great example of what's wrong with Calgary pla...              T
# 3    @kirstengoa I keep telling city planners every...              T
# 4    @nenshi Just what we don’t need is more freaki...              T
# ..                                                 ...            ...
# 296  Oh god. I'm watching a video comparing bike ri...              T
# 297  @Canadabuster Shutdown and Lockdown the Calgar...              T
# 298  Calgary is a great example of a city that has ...              T
# 299  @brian_gettler @tpcanoe @ianmilligan1 I expect...              T
# 300                                                  0              0
#
#     Reeshad - actionable Divyansh - eval Divyansh - actionable Kirtan - eval  \
# ...

# %%
# Normalize data3's Data
i = 0
#data2['Kirtan - actionable'] = data2['Kirtan - actionable'].apply(str)
data3['Kirtan - eval'] = data3['Kirtan']
for val in data3['Kirtan - eval']: 
    if val == 't':
        data3.at[data3.index[i],'Kirtan - eval'] = 'T'
        data3.at[data3.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 'T':
        data3.at[data3.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 0:
        data3.at[data3.index[i],'Kirtan - eval'] = 'F'
        data3.at[data3.index[i],'Kirtan - actionable'] = 'NA'
        
    if val == 'ta' or val == 'TA':
        data3.at[data3.index[i],'Kirtan - eval'] = 'T'
        data3.at[data3.index[i],'Kirtan - actionable'] = 'A'
    
    i = i + 1
    
    
i = 0
#data1['Reeshad - actionable'] = data1['Reeshad - actionable'].apply(str)
for val in data3['Reeshad - actionable']: 
#    if val == 't':
#        data1.at[data1.index[i],'Reeshad - eval'] = 'T'
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
#    if val == 'T':
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
#    if val == 0:
#        data1.at[data1.index[i],'Reeshad - eval'] = 'F'
#        data1.at[data1.index[i],'Reeshad - actionable'] = 'NA'
        
    if val == 'FA':
        data3.at[data3.index[i],'Reeshad - actionable'] = 'NA'
        
    if val == 'TA':
        data3.at[data3.index[i],'Reeshad - actionable'] = 'A'
    
    i = i + 1
    

i = 0
#data1['Divyansh - actionable'] = data1['Divyansh - actionable'].apply(str)
for val1 in data3['Divyansh - eval']: 
    if val1 == 'n':
        data3.at[data3.index[i],'Divyansh - eval'] = 'F'
        data3.at[data3.index[i],'Divyansh - actionable'] = 'NA'
        
    if val1 == 'y':
        data3.at[data3.index[i],'Divyansh - eval'] = 'T'
    i = i + 1
    

i = 0        
for val2 in data3['Divyansh - actionable']:
    if val2 == '-':
        data3.at[data3.index[i],'Divyansh - actionable'] = 'NA'
        
    if val2 == 'y':
        data3.at[data3.index[i],'Divyansh - actionable'] = 'A'
        
    if val2 == 'n':
        data3.at[data3.index[i],'Divyansh - actionable'] = 'NA'
    
    i = i + 1
    
data3 = data3.drop(columns=['Kirtan'])
    
data3
# Out:
#                                                  text Reeshad - eval  \
# 0   In other words, we have a pedestrian incident ...              T
# 1   So the boulevard is once again mowed (as per @...              T
# 2   "Since the incident, the city told the family ...              T
# 3   A short video about the worst street in my cit...              F
# 4   This is why cycling infrastructure is so impor...              T
# 5   Are engineers and electeds using simple fixes ...              T
# 6   But you know, pedestrians need to me more aler...              T
# 7   @troutwhispers More covid policy stupidity...t...              T
# 8   Community Safety Action 4: Smart City Planning...              T
# 9   Vehicles must Yield to Cyclists and Pedestrian...              T
# 10  Some positivity: seeing terrifying videos of b...              T
# 11  @projectstartrek @MTA In 2001 in Calgary on a ...              T
# 12  Shame @cityofcalgary clearing 42 Ave bike path...              T
# ...

# %%
data1 = data1.append(data2, ignore_index=True)
data1 = data1.append(data3, ignore_index=True)
# Out:
# C:\Users\drana\AppData\Local\Temp\ipykernel_26596\2051319232.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data1 = data1.append(data2, ignore_index=True)
# C:\Users\drana\AppData\Local\Temp\ipykernel_26596\2051319232.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data1 = data1.append(data3, ignore_index=True)

# %%
from transformers import pipeline
classifier = pipeline("text-classification",model='bhadresh-savani/distilbert-base-uncased-emotion', return_all_scores=True)
#prediction = classifier("I love using transformers. The best part is wide range of support and its easy to use", )
#print(prediction)
# Out:
# C:\Users\drana\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text_classification.py:89: UserWarning: `return_all_scores` is now deprecated, use `top_k=1` if you want similar functionnality
#   warnings.warn(

# %%
new_arr = []
for text in data1['text']:
    text1 = str(text)
    new_arr.append(text1)

# %%
prediction_arr = classifier(new_arr)
print(prediction_arr)
# Out:
# [[{'label': 'sadness', 'score': 0.02040466107428074}, {'label': 'joy', 'score': 0.031192632392048836}, {'label': 'love', 'score': 0.0015353644266724586}, {'label': 'anger', 'score': 0.7704400420188904}, {'label': 'fear', 'score': 0.17482227087020874}, {'label': 'surprise', 'score': 0.001605051220394671}], [{'label': 'sadness', 'score': 0.0247490331530571}, {'label': 'joy', 'score': 0.38090574741363525}, {'label': 'love', 'score': 0.0031528302934020758}, {'label': 'anger', 'score': 0.35992422699928284}, {'label': 'fear', 'score': 0.22683894634246826}, {'label': 'surprise', 'score': 0.004429210908710957}], [{'label': 'sadness', 'score': 0.008689353242516518}, {'label': 'joy', 'score': 0.9013569355010986}, {'label': 'love', 'score': 0.0018795101204887033}, {'label': 'anger', 'score': 0.038246095180511475}, {'label': 'fear', 'score': 0.0483582429587841}, {'label': 'surprise', 'score': 0.0014698635786771774}], [{'label': 'sadness', 'score': 0.000821997644379735}, {'label': 'joy', 'score':
# ...

# %%
print(len(prediction_arr))
print(prediction_arr[0][0]['score'])
# Out:
# 468
# 0.02040466107428074

# %%
main_prediction_arr = []
for i in range(len(prediction_arr)):
    max_score = prediction_arr[i][0]['score']
    for j in range(len(prediction_arr[i])):
        if prediction_arr[i][j]['score'] > max_score:
            max_score = prediction_arr[i][j]['score']
    

    for l in range(len(prediction_arr[i])):
        if prediction_arr[i][l]['score'] == max_score:
            main_prediction_arr.append(prediction_arr[i][l])
            
print(main_prediction_arr)
print(len(main_prediction_arr))
# Out:
# [{'label': 'anger', 'score': 0.7704400420188904}, {'label': 'joy', 'score': 0.38090574741363525}, {'label': 'joy', 'score': 0.9013569355010986}, {'label': 'joy', 'score': 0.9956294298171997}, {'label': 'joy', 'score': 0.9530794620513916}, {'label': 'joy', 'score': 0.9962208867073059}, {'label': 'joy', 'score': 0.6033830642700195}, {'label': 'joy', 'score': 0.7643583416938782}, {'label': 'anger', 'score': 0.4979706406593323}, {'label': 'joy', 'score': 0.9470950961112976}, {'label': 'joy', 'score': 0.9532092213630676}, {'label': 'joy', 'score': 0.7912164926528931}, {'label': 'joy', 'score': 0.9419710040092468}, {'label': 'anger', 'score': 0.9975233674049377}, {'label': 'anger', 'score': 0.9237640500068665}, {'label': 'joy', 'score': 0.9370691180229187}, {'label': 'joy', 'score': 0.9195645451545715}, {'label': 'anger', 'score': 0.8728938698768616}, {'label': 'anger', 'score': 0.9428840279579163}, {'label': 'anger', 'score': 0.5387139916419983}, {'label': 'joy', 'score': 0.97330462932586
# ...

# %%
data1['emotion'] = 'Default'
data1['emotion_score'] = 'Default'
for i in range(len(data1['text'])):
    data1['emotion'][i] = main_prediction_arr[i]['label']
    data1['emotion_score'][i] = main_prediction_arr[i]['score']
    
print(data1)
# Out:
#                                                   text Kirtan - eval  \
# 0    Drinking in Calgary's parks: pilot program a s...             F
# 1    Wow. “Starting June 1st, COVID restrictions pe...             T
# 2    Drinking in Calgary parks could soon be a real...             T
# 3    Calgary should get with the times and join the...             T
# 4    @scryed88 @cityofcalgary I’m the last guy on t...             T
# ..                                                 ...           ...
# 463  @betamanic The City if Calgary automated "butt...             T
# 464  Governments will tell you they prioritise safe...             T
# 465  It might make the actual news &amp; be 1000% b...             T
# 466  @mikesbloggity @cityofcalgary City hasn't weig...             T
# 467  This: \n\nIt’s important if we want youth to c...             F
#
#     Kirtan - actionable Reeshad - eval Reeshad - actionable Divyansh - eval  \
# ...

# %%
data1.to_csv('example_normalized.csv')

# %%
data =  pd.read_csv('example_normalized.csv')

# %%
# 18 August


# For finding correlation between count of (fearful and actionable tweets) and actionable tweets

data_sorted = data.copy()

correlation1_sum = 0
correlation2_sum = 0
correlation3_sum = 0
correlation4_sum = 0
correlation5_sum = 0
correlation6_sum = 0

total_count_fear = 0
total_count_anger = 0
total_count_joy = 0
total_count_love = 0
total_count_surprise = 0
total_count_sadness = 0
total_count_action = 0

for a in range(0,200,1):
    data_sorted = data_sorted.sample(frac=1)

    count_fear = 0
    count_anger = 0
    count_joy = 0
    count_love = 0
    count_surprise = 0
    count_sadness = 0
    count_action = 0

    i = 0
    count = 0;

    for emoti in data_sorted['emotion']:
        count = count + 1
        total_count_fear = total_count_fear + count_fear
        total_count_anger = total_count_anger + count_anger
        total_count_joy = total_count_joy + count_joy 
        total_count_love = total_count_love + count_love
        total_count_surprise = total_count_surprise + count_surprise
        total_count_sadness = total_count_sadness + count_sadness
        total_count_action = total_count_action + count_action
        # 1000/10 = 100 data points
        if(count == 10):
            k = i-10
            for l in range(k,i,1):
                data_sorted.at[data_sorted.index[l],'count_of_fear_emotion'] = count_fear
                data_sorted.at[data_sorted.index[l],'count_of_anger_emotion'] = count_anger
                data_sorted.at[data_sorted.index[l],'count_of_joy_emotion'] = count_joy
                data_sorted.at[data_sorted.index[l],'count_of_love_emotion'] = count_love
                data_sorted.at[data_sorted.index[l],'count_of_surprise_emotion'] = count_surprise
                data_sorted.at[data_sorted.index[l],'count_of_sadness_emotion'] = count_sadness
                data_sorted.at[data_sorted.index[l],'count_Actionability'] = count_action

    #            if data_sorted.at[data_sorted.index[l],'Actionability'] == 'T' and data_sorted.at[data_sorted.index[l],'Actionability_2'] == 'T':
    #                print(data_sorted.at[data_sorted.index[l],'text'])

    #        print(count_action)
    #        print()
    #        print()
    #        print("Actionability tweets")
    #        print()
    #        print()
    #        total_count = count_fear + count_anger + count_joy + count_love + count_surprise + count_sadness

    #        print('percentage of fearful tweets : ' + ((str)((count_fear/total_count) *100)  +'%'))
    #        print('percentage of angry tweets : ' + ((str)((count_anger/total_count) *100)  +'%'))
    #        print('percentage of joyful tweets : ' + ((str)((count_joy/total_count) *100)  +'%'))
    #        print('percentage of lovable tweets : ' + ((str)((count_love/total_count) *100)  +'%'))
    #        print('percentage of surprise tweets : ' + ((str)((count_surprise/total_count) *100)  +'%'))
    #        print('percentage of sadness tweets : ' + ((str)((count_sadness/total_count) *100)  +'%'))
    #        print()

            count = 0
            count_fear = 0
            count_anger = 0
            count_joy = 0
            count_love = 0
            count_surprise = 0
            count_sadness = 0
            count_action = 0


        if emoti == 'fear':
            count_fear = count_fear + 1

        if emoti == 'anger':
            count_anger = count_anger + 1

        if emoti == 'joy':
            count_joy = count_joy + 1 

        if emoti == 'love':
            count_love = count_love + 1 

        if emoti == 'surprise':
            count_surprise = count_surprise + 1 

        if emoti == 'sadness':
            count_sadness = count_sadness + 1 
        
        bool = 0
#        if data_sorted.at[data_sorted.index[i],'Reeshad - eval'] == 'T' :
        if data_sorted.at[data_sorted.index[i],'Reeshad - actionable'] == 'A' :
                bool = bool + 1
#        if data_sorted.at[data_sorted.index[i],'Kirtan - eval'] == 'T' :
        if data_sorted.at[data_sorted.index[i],'Kirtan - actionable'] == 'A' :
                bool =  bool + 1
#        if data_sorted.at[data_sorted.index[i],'Divyansh - eval'] == 'T' :
        if data_sorted.at[data_sorted.index[i],'Divyansh - actionable'] == 'A' :
                bool =  bool + 1
                
        if (bool >=2):
            count_action = count_action + 1




        i= i +1 


    correlation1 = data_sorted.corr()
    correlation1_sum = correlation1_sum + correlation1.loc['count_of_fear_emotion', 'count_Actionability']

    correlation2 = data_sorted.corr()
    correlation2_sum = correlation2_sum + correlation2.loc['count_of_anger_emotion', 'count_Actionability']

    correlation3 = data_sorted.corr()
    correlation3_sum = correlation3_sum + correlation3.loc['count_of_joy_emotion', 'count_Actionability']

    correlation4 = data_sorted.corr()
    correlation4_sum = correlation4_sum + correlation4.loc['count_of_love_emotion', 'count_Actionability']

    correlation5 = data_sorted.corr()
    correlation5_sum = correlation5_sum + correlation5.loc['count_of_sadness_emotion', 'count_Actionability']

    correlation6 = data_sorted.corr()
    correlation6_sum = correlation6_sum + correlation6.loc['count_of_surprise_emotion', 'count_Actionability']

print('fear coorelation: ' + str(correlation1_sum/200))
print('anger coorelation: ' + str(correlation2_sum/200))
print('joy coorelation: ' + str(correlation3_sum/200))
print('love coorelation: ' + str(correlation4_sum/200))
print('sadness coorelation: ' + str(correlation5_sum/200))
print('surprise coorelation: ' + str(correlation6_sum/200))
# Out:
# fear coorelation: 0.035585725866989264
# anger coorelation: -0.09659885842049692
# joy coorelation: 0.0926786434332028
# love coorelation: -0.056766519363921276
# sadness coorelation: -0.014115246770558167
# surprise coorelation: -0.027578499431117388

# %%
# bad results, overwhemling emotion gives bad results
# also could be due to limited data
# eg: percentage of fearful tweets : 6.837606837606838%
#     percentage of angry tweets : 23.29059829059829%
#     percentage of joyful tweets : 60.256410256410255%

#     total_actionable tweets with fear emotion(considered actionable by 2/3 markers) :3
#     total_actionable tweets with joy emotion(considered actionable by 2/3 markers) :25
#     total_actionable tweets with anger emotion(considered actionable by 2/3 markers) :5

# also our percentage methodology fails fails
# main result

# %%
# Old methodology
data_sorted = data.copy()
# counting actionable and number of emotional tweets over the sorted database, 
# Only one annotator for now




count_fear = 0
count_anger = 0
count_joy = 0
count_love = 0
count_surprise = 0
count_sadness = 0
count_action = 0

i = 0

for emoti in data_sorted['emotion']:

    if emoti == 'fear':
        count_fear = count_fear + 1

    if emoti == 'anger':
        count_anger = count_anger + 1
        
    if emoti == 'joy':
        count_joy = count_joy + 1 
        
    if emoti == 'love':
        count_love = count_love + 1 
        
    if emoti == 'surprise':
        count_surprise = count_surprise + 1 
        
    if emoti == 'sadness':
        count_sadness = count_sadness + 1 
        
        

       
       
    data_sorted.at[data_sorted.index[i],'count_of_fear_emotion'] = count_fear
    data_sorted.at[data_sorted.index[i],'count_of_anger_emotion'] = count_anger
    data_sorted.at[data_sorted.index[i],'count_of_joy_emotion'] = count_joy
    data_sorted.at[data_sorted.index[i],'count_of_love_emotion'] = count_love
    data_sorted.at[data_sorted.index[i],'count_of_surprise_emotion'] = count_surprise
    data_sorted.at[data_sorted.index[i],'count_of_sadness_emotion'] = count_sadness
        
    i= i +1 
   
total_count = count_fear + count_anger + count_joy + count_love + count_surprise + count_sadness

print('percentage of fearful tweets : ' + ((str)((count_fear/total_count) *100)  +'%'))
print('percentage of angry tweets : ' + ((str)((count_anger/total_count) *100)  +'%'))
print('percentage of joyful tweets : ' + ((str)((count_joy/total_count) *100)  +'%'))
print('percentage of lovable tweets : ' + ((str)((count_love/total_count) *100)  +'%'))
print('percentage of surprise tweets : ' + ((str)((count_surprise/total_count) *100)  +'%'))
print('percentage of sadness tweets : ' + ((str)((count_sadness/total_count) *100)  +'%'))
# Out:
# percentage of fearful tweets : 6.837606837606838%
# percentage of angry tweets : 23.29059829059829%
# percentage of joyful tweets : 60.256410256410255%
# percentage of lovable tweets : 1.7094017094017095%
# percentage of surprise tweets : 0.641025641025641%
# percentage of sadness tweets : 7.264957264957266%

# %%
# Probability of a tweet being actionable by both the markers if it's emotion is fearful

i = 0 
total_fear = 0
action_if_fear = 0
for emoti in data_sorted['emotion']:
    if emoti == 'fear':
        total_fear = total_fear + 1
        actionable_count = 0
        if data_sorted.at[data_sorted.index[i],'Reeshad - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Kirtan - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Divyansh - actionable'] == 'A' :
            actionable_count = actionable_count + 1
            if actionable_count == 2 or actionable_count == 3:
                action_if_fear = action_if_fear + 1
            
    i = i + 1
    
Percentage_fear_action = action_if_fear / total_fear

print('Probablity that a tweet is actionable(by 2/3 markers) if it is fearful :' + str(Percentage_fear_action))
# Out:
# Probablity that a tweet is actionable(by 2/3 markers) if it is fearful :0.09375

# %%
# Probability of a tweet being actionable by both markers if it's emotion is other than fearful

i = 0 
total_joy = 0
total_anger = 0
total_love = 0
total_sadness = 0
total_surprise = 0
action_if_joy = 0
action_if_anger = 0
action_if_love = 0
action_if_sadness = 0
action_if_surprise = 0
for emoti in data_sorted['emotion']:
    if emoti == 'joy':
        total_joy = total_joy + 1
        actionable_count = 0
        if data_sorted.at[data_sorted.index[i],'Reeshad - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Kirtan - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Divyansh - actionable'] == 'A' :
            actionable_count = actionable_count + 1
            if actionable_count == 2 or actionable_count == 3:
                action_if_joy = action_if_joy + 1
    if emoti == 'anger':
        total_anger = total_anger + 1
        actionable_count = 0
        if data_sorted.at[data_sorted.index[i],'Reeshad - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Kirtan - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Divyansh - actionable'] == 'A' :
            actionable_count = actionable_count + 1
            if actionable_count == 2 or actionable_count == 3:
                action_if_anger = action_if_anger + 1
            
    if emoti == 'love':
        total_love = total_love + 1
        actionable_count = 0
        if data_sorted.at[data_sorted.index[i],'Reeshad - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Kirtan - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Divyansh - actionable'] == 'A' :
            actionable_count = actionable_count + 1
            if actionable_count == 2 or actionable_count == 3:
                action_if_love = action_if_love + 1
            
    if emoti == 'sadness':
        total_sadness = total_sadness + 1
        actionable_count = 0
        if data_sorted.at[data_sorted.index[i],'Reeshad - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Kirtan - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Divyansh - actionable'] == 'A' :
            actionable_count = actionable_count + 1
            if actionable_count == 2 or actionable_count == 3:
                action_if_sadness = action_if_sadness + 1
            
    if emoti == 'surprise':
        total_surprise = total_surprise + 1
        actionable_count = 0
        if data_sorted.at[data_sorted.index[i],'Reeshad - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Kirtan - actionable'] == 'A':
            actionable_count = actionable_count + 1
        if data_sorted.at[data_sorted.index[i],'Divyansh - actionable'] == 'A' :
            actionable_count = actionable_count + 1
            if actionable_count == 2 or actionable_count == 3:
                action_if_surprise = action_if_surprise + 1
            
    i = i + 1
    
Percentage_joy_action = action_if_joy / total_joy
Percentage_anger_action = action_if_anger / total_anger
Percentage_love_action = action_if_love / total_love
Percentage_sadness_action = action_if_sadness / total_sadness
Percentage_surprise_action = action_if_surprise / total_surprise

print('Probablity that a tweet is actionable(by 2/3 markers) if it is joyful :' + str(Percentage_joy_action))
print('Probablity that a tweet is actionable(by 2/3 markers) if it is angry :' + str(Percentage_anger_action))
print('Probablity that a tweet is actionable(by 2/3 markers) if it is lovable :' + str(Percentage_love_action))
print('Probablity that a tweet is actionable(by 2/3 markers) if it is sadness :' + str(Percentage_sadness_action))
print('Probablity that a tweet is actionable(by 2/3 markers) if it is surprising :' + str(Percentage_surprise_action))
# Out:
# Probablity that a tweet is actionable(by 2/3 markers) if it is joyful :0.08865248226950355
# Probablity that a tweet is actionable(by 2/3 markers) if it is angry :0.045871559633027525
# Probablity that a tweet is actionable(by 2/3 markers) if it is lovable :0.0
# Probablity that a tweet is actionable(by 2/3 markers) if it is sadness :0.029411764705882353
# Probablity that a tweet is actionable(by 2/3 markers) if it is surprising :0.0

# %%
total_actionable = action_if_fear + action_if_joy + action_if_anger + action_if_love + action_if_sadness + action_if_surprise
print('total_actionable tweets(considered actionable by 2/3 markers) :' + str(total_actionable))

print('total_actionable tweets with fear emotion(considered actionable by 2/3 markers) :' + str(action_if_fear))
print('total_actionable tweets with joy emotion(considered actionable by 2/3 markers) :' + str(action_if_joy))
print('total_actionable tweets with anger emotion(considered actionable by 2/3 markers) :' + str(action_if_anger))
# Out:
# total_actionable tweets(considered actionable by 2/3 markers) :34
# total_actionable tweets with fear emotion(considered actionable by 2/3 markers) :3
# total_actionable tweets with joy emotion(considered actionable by 2/3 markers) :25
# total_actionable tweets with anger emotion(considered actionable by 2/3 markers) :5

# %%
df1 = pd.DataFrame({'emotion_count': [total_count_fear, total_count_joy , total_count_anger, total_count_love, total_count_sadness, total_count_surprise]},
                  index=['fear', 'joyful', 'anger', 'love', 'sadness','surprise'])
plot = df1.plot.pie(y='emotion_count')
df2 = pd.DataFrame({'actionable_count': [action_if_fear, action_if_joy , action_if_anger, action_if_love, action_if_sadness, action_if_surprise]},
                  index=['fear', 'joyful', 'anger', 'love', 'sadness','surprise'])
plot = df2.plot.pie(y='actionable_count')
